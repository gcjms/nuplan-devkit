# %% [markdown]
# ![](https://www.nuplan.org/static/media/nuPlan_final.3fde7586.png)

# %% [markdown]
# ### Contents
#
# 1. [Introduction to nuPlan](#introduction)
# 2. [Training an ML planner](#training)
# 3. [Simulating a planner](#simulation)
# 4. [Visualizing metrics and scenarios](#dashboard)

# %%
from tutorials.utils.tutorial_utils import setup_notebook

setup_notebook()

# %% [markdown]
# # Introduction to nuPlan <a name="introduction"></a>

# %% [markdown]
# Welcome to nuPlan! This notebook will explore the nuPlan simulation framework, training platform as well as the nuBoard metrics/scenarios visualization dashboard.

# %% [markdown]
# ## What is nuPlan
#
# nuPlan is the world’s first closed-loop ML-based planning benchmark for autonomous driving.
#
# It provides a high quality dataset with 1500h of human driving data from 4 cities across the US and Asia with widely varying traffic patterns (Boston, Pittsburgh, Las Vegas and Singapore). In addition, it provides a closed-loop simulation framework with reactive agents, a training platform as well as a large set of both general and scenario-specific planning metrics.
#
# ![](https://www.nuscenes.org/static/media/framework_steps.2d4642df.png)

# %% [markdown]
# ## Training & simulation framework
#
# The nuPlan training and simulation framework aims to:
# * create a simulation pipeline to evaluate a planner on large dataset with various scenarios
# * score planner performance with common and scenario-dependent metrics
# * compare planners based on measured metrics and provide intuitive visualizations
# * train planners with the provided framework to allow quick implementation and iteration
# * support closed-loop simulation and training
#
# <br />
#
# ![](https://www.nuplan.org/static/media/planning_framework.ca3c2969.png)

# %% [markdown]
# ## Scenarios in nuPlan
#
# nuPlan aims to capture challenging yet representative scenarios from real-world encounters. This enables the benchmarking of planning systems both in expert imitation (open-loop) and reactive planning (closed-loop) settings.
#
# These scenarios includes:
# * highly interactive scenes with traffic participants (e.g. tailgating, high-velocity overtakes, double parked cars, jaywalking)
# * various ego behaviors (e.g. vehicle following, yielding, lane merging) and dynamics (e.g. mixed speed profiles, abrupt braking, speed bumps, high jerk maneuvers)
# * scene layouts of varied complexity (e.g. pudos, traffic/stop controlled intersections, unprotected turns) and temporary zones (e.g. construction areas)
#
# The dataset is automatically tagged with scenario labels based on certain primitive attributes.
# These scenario tags can then be used to extract representative metrics for the planner's evaluation.
#
# Example mined scenarios in nuPlan:
#
# | | | |
# | :-: | :-: | :-: |
# | Unprotected cross turn | Dense vehicle interactions | Jaywalker in front |
# | ![](https://www.nuscenes.org/static/media/unprotected-cross.51feef7e.webp) | ![](https://www.nuscenes.org/static/media/dense-interactions.16de47ec.webp) | ![](https://www.nuscenes.org/static/media/jaywalker.03083823.webp) |
# | Lane change | Ego at pickup/dropoff area | Ego following vehicle |
# | ![](https://www.nuscenes.org/static/media/lane-change.54bfca1c.webp) | ![](https://www.nuscenes.org/static/media/pickup-dropoff.4dd1c418.webp) | ![](https://www.nuscenes.org/static/media/following-vehicle.4cacd559.webp) |

# %% [markdown]
# ## Database
#
# Download a database for training/simulation from [here](https://nuplan.org/nuplan#download).
#
# | Database | Size | Duration | Num Logs | Cities | Num Scenarios | Sensor Data | Description |
# | :-- | :-- | :-- | :-- | :-- | :-- | :-- | :-- |
# | nuplan_v1.1_mini (recommended) | 13GB | 7h | 64 | Las Vegas, Boston, Pittsburgh, Singapore | 67 | N/A | The mini split used for prototyping and testing |
# | nuplan_v1.1 | 1.8TB | 1282h | 15910 | Las Vegas, Boston, Pittsburgh, Singapore | 73 | N/A | The full dataset for training and evaluation|

# %% [markdown]
# ## Setup
#
# To be able to access all resources within this notebook, make sure Jupyter is launched at the root of this repo. The path of the notebook should be `/notebook/<repo_root>`.

# %%
# (Optional) Increase notebook width for all embedded cells to display properly
from IPython.core.display import display, HTML
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_93489/4180358289.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.output_result { max-width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %%
# Useful imports
import os
from pathlib import Path
import tempfile

import hydra

# %%
import os
os.getcwd()
# Out:
# '/home/gcjms/nuplan-devkit'

# %%
# %cd /home/gcjms/nuplan-devkit
# Out:
# /home/gcjms/nuplan-devkit

# %% [markdown]
# # Training an ML planner <a name="training"></a>

# %% [markdown]
# ## Imitation learning
# In the following section we will train an ML planning policy with the aim estimate the ego's future trajectory and control the vehicle.
#
# The policy is learned through imitation learning, a supervised learning approach in which - in the context of autonomous driving - the behavior of an expert human driver is used as a target signal to supervise the model.
#
# ## Model features & targets
# A planning policy consumes a set of episodic observations and encodes them through a deep neural network to regress a future trajectory.
#
# The observations can be historic or present ego and agent poses as well as static/dynamic map information across different map layers.<br />
# These signals can be encoded through various representations, such as raster or vector format for the map signal, each with their pros and cons for each model flavor.
#
# Using these input features the model predicts a discretized future trajectory across a fixed time horizon.<br />
# The trajectory consists of a set of discrete future states (position, heading and velocity) sampled at fixed intervals which express the likelihood of the vehicle being at that state in the future.<br />
# For example, a predicted trajectory may consist of 10 future poses sampled at intervals of 0.5s across a 5s horizon.
#
# ## Learning objectives
# The policy is trained to maximize a set of aggregated objectives such as imitation, collision avoidance, traffic rule violation etc.<br />
# Imitation is the core training objective which indicates how close the predicted trajectory is to the expert ground truth and penalizes model predictions that deviate in space and time from the demonstration.

# %% [markdown]
# ## Training parameters

# %% [markdown]
# The following parameter categories define the training protocol which includes the model, metrics, objectives etc.
#
# A working example composition of these parameters can be found in the next section.
#
# ---
#
# ### ML models
#
# Change the training model with `model=X` where `X` is a config yaml defined in the table below.
#
# | Model | Description | Config |
# | --- | --- | --- |
# | Raster model (CNN) | Raster-based model that uses a CNN backbone to encode ego, agent and map information as raster layers<br />Any (pretrained) backbone from the TIMM library can be used (e.g. ResNet50, EfficientNetB3) | `raster_model` |
# | Vector model (LaneGCN) | Vector-based model that uses a series of MLPs to encode ego and agent signals, a lane graph to encode vector-map elements and a fusion network to capture lane & agent intra/inter-interactions through attention layers<br />Implementation of LaneGCN paper ("Learning Lane Graph Representations for Motion Forecasting") | `vector_model` |
# | Simple vector model | Toy vector-based model that consumes ego, agent and lane signals through a series of MLPs | `simple_vector_model` |
#
# <br />
#
# ### Training objectives
#
# Change the training objectives with `objective=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Objective | Description | Config |
# | --- | --- | --- |
# | Imitation objective | Penalizes the predicted trajectory that deviates from the expert demonstration | `imitation_objective` |
#
# <br />
#
# ### Training metrics
#
# Change the training objectives with `training_metric=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Metric | Description | Config |
# | --- | --- | --- |
# | Average displacement error | RMSE translation error across full predicted trajectory | `avg_displacement_error` |
# | Average heading error | RMSE heading error across full predicted trajectory | `avg_heading_error` |
# | Final displacement error | L2 error of predicted trajectory's final pose translation | `final_displacement_error` |
# | Final heading error | L2 error of predicted trajectory's final pose heading | `final_heading_error` |

# %% [markdown]
# ## Prepare the training config

# %%
# Location of path with all training configs
CONFIG_PATH = '../nuplan/planning/script/config/training'
# default_training.yaml
CONFIG_NAME = 'default_training'

# Create a temporary directory to store the cache and experiment artifacts
SAVE_DIR = Path(tempfile.gettempdir()) / 'tutorial_nuplan_framework'  # optionally replace with persistent dir
EXPERIMENT = 'training_raster_experiment'
JOB_NAME = 'train_default_raster'
LOG_DIR = SAVE_DIR / EXPERIMENT / JOB_NAME

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'group={str(SAVE_DIR)}',
    f'cache.cache_path={str(SAVE_DIR)}/cache',
    f'experiment_name={EXPERIMENT}',
    f'job_name={JOB_NAME}',
    'py_func=train',
    '+training=training_raster_model',  # raster model that consumes ego, agents and map raster layers and regresses the ego's trajectory
    'scenario_builder=nuplan_mini',  # use nuplan mini database
     
    'scenario_filter.limit_total_scenarios=50',  # Choose 500 scenarios to train with
    'lightning.trainer.params.accelerator=ddp_spawn',  # ddp is not allowed in interactive environment, using ddp_spawn instead - this can bottleneck the data pipeline, it is recommended to run training outside the notebook
    'lightning.trainer.params.max_epochs=1',
    'data_loader.params.batch_size=8',
    'data_loader.params.num_workers=8',
])

# %% [markdown]
# ## Launch tensorboard for visualizing training artifacts

# %%
# %load_ext tensorboard
# %tensorboard --logdir {str(LOG_DIR)}
# Out:
# Reusing TensorBoard on port 6006 (pid 912), started 2 days, 0:08:06 ago. (Use '!kill 912' to kill it.)
#       <iframe id="tensorboard-frame-af26cedc077b60dd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-af26cedc077b60dd");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Launch training (within the notebook)

# %%
from nuplan.planning.script.run_training import main as main_train

# Run the training loop, optionally inspect training artifacts through tensorboard (above cell)
main_train(cfg)
# Out:
# Global seed set to 0
# 2025-11-20 00:42:33,821 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:20}  Building experiment folders...
# 2025-11-20 00:42:33,822 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:22}  Experimental folder: /tmp/tutorial_nuplan_framework/training_raster_experiment/train_default_raster/2025.11.20.00.42.06
# 2025-11-20 00:42:33,822 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2025-11-20 00:42:33,823 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: SingleMachineParallelExecutor
# 2025-11-20 00:42:33,823 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 4
# Number of GPUs per node: 0
# Number of threads across all nodes: 4
# 2025-11-20 00:42:33,823 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2025-11-20 00:42:33,824 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/training/experiments/training.py:41}  Building training engine...
# 2025-11-20 00:42:33,824 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-20 00:42:34,209 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 4
#       1 from nuplan.planning.script.run_training import main as main_train
#       3 # Run the training loop, optionally inspect training artifacts through tensorboard (above cell)
# ----> 4 main_train(cfg)
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/hydra/main.py:43, in main.<locals>.main_decorator.<locals>.decorated_main(cfg_passthrough)
#      40 @functools.wraps(task_function)
#      41 def decorated_main(cfg_passthrough: Optional[DictConfig] = None) -> Any:
#      42     if cfg_passthrough is not None:
# ---> 43         return task_function(cfg_passthrough)
#      44     else:
#      45         args = get_args_parser()
#
# File ~/nuplan-devkit/nuplan/planning/script/run_training.py:61, in main(cfg)
#      58 if cfg.py_func == 'train':
#      59     # Build training engine , ProfilerContextManager性能统计 类似火焰图
#      60     with ProfilerContextManager(cfg.output_dir, cfg.enable_profiling, "build_training_engine"):
# ---> 61         engine = build_training_engine(cfg, worker)
#      63     # Run training
#      64     logger.info('Starting training...')
#
# File ~/nuplan-devkit/nuplan/planning/training/experiments/training.py:44, in build_training_engine(cfg, worker)
#      41 logger.info('Building training engine...')
#      43 # Create model
# ---> 44 torch_module_wrapper = build_torch_module_wrapper(cfg.model)
#      46 # Build the datamodule
#      47 datamodule = build_lightning_datamodule(cfg, worker, torch_module_wrapper)
#
# File ~/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:19, in build_torch_module_wrapper(cfg)
#      13 """
#      14 Builds the NN module.
#      15 :param cfg: DictConfig. Configuration that is used to run the experiment.
#      16 :return: Instance of TorchModuleWrapper.
#      17 """
#      18 logger.info('Building TorchModuleWrapper...')
# ---> 19 model = instantiate(cfg)
#      20 validate_type(model, TorchModuleWrapper)
#      21 logger.info('Building TorchModuleWrapper...DONE!')
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/instantiate/_instantiate2.py:218, in instantiate(config, *args, **kwargs)
#     215     _convert_ = config.pop(_Keys.CONVERT, ConvertMode.NONE)
#     216     _partial_ = config.pop(_Keys.PARTIAL, False)
# --> 218     return instantiate_node(
#     219         config, *args, recursive=_recursive_, convert=_convert_, partial=_partial_
#     220     )
#     221 elif OmegaConf.is_list(config):
#     222     # Finalize config (convert targets to strings, merge with kwargs)
#     223     config_copy = copy.deepcopy(config)
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/instantiate/_instantiate2.py:331, in instantiate_node(node, convert, recursive, partial, *args)
#     326                 value = instantiate_node(
#     327                     value, convert=convert, recursive=recursive
#     328                 )
#     329             kwargs[key] = _convert_node(value, convert)
# --> 331     return _call_target(_target_, partial, args, kwargs, full_key)
#     332 else:
#     333     # If ALL or PARTIAL non structured, instantiate in dict and resolve interpolations eagerly.
#     334     if convert == ConvertMode.ALL or (
#     335         convert == ConvertMode.PARTIAL and node._metadata.object_type is None
#     336     ):
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/instantiate/_instantiate2.py:86, in _call_target(_target_, _partial_, args, kwargs, full_key)
#      84 else:
#      85     try:
# ---> 86         return _target_(*args, **kwargs)
#      87     except Exception as e:
#      88         msg = f"Error in call to target '{_convert_target_to_string(_target_)}':\n{repr(e)}"
#
# File ~/nuplan-devkit/nuplan/planning/training/modeling/models/raster_model.py:58, in RasterModel.__init__(self, feature_builders, target_builders, model_name, pretrained, num_input_channels, num_features_per_pose, future_trajectory_sampling)
#      51 super().__init__(
#      52     feature_builders=feature_builders,
#      53     target_builders=target_builders,
#      54     future_trajectory_sampling=future_trajectory_sampling,
#      55 )
#      57 num_output_features = future_trajectory_sampling.num_poses * num_features_per_pose
# ---> 58 self._model = timm.create_model(model_name, pretrained=pretrained, num_classes=0, in_chans=num_input_channels)
#      59 mlp = torch.nn.Linear(in_features=self._model.num_features, out_features=num_output_features)
#      61 if hasattr(self._model, 'classifier'):
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_factory.py:138, in create_model(model_name, pretrained, pretrained_cfg, pretrained_cfg_overlay, checkpoint_path, cache_dir, scriptable, exportable, no_jit, **kwargs)
#     136 create_fn = model_entrypoint(model_name)
#     137 with set_layer_config(scriptable=scriptable, exportable=exportable, no_jit=no_jit):
# --> 138     model = create_fn(
#     139         pretrained=pretrained,
#     140         pretrained_cfg=pretrained_cfg,
#     141         pretrained_cfg_overlay=pretrained_cfg_overlay,
#     142         cache_dir=cache_dir,
#     143         **kwargs,
#     144     )
#     146 if checkpoint_path:
#     147     load_checkpoint(model, checkpoint_path)
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/resnet.py:1552, in resnet50(pretrained, **kwargs)
#    1549 """Constructs a ResNet-50 model.
#    1550 """
#    1551 model_args = dict(block=Bottleneck, layers=(3, 4, 6, 3))
# -> 1552 return _create_resnet('resnet50', pretrained, **dict(model_args, **kwargs))
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/resnet.py:791, in _create_resnet(variant, pretrained, **kwargs)
#     780 def _create_resnet(variant: str, pretrained: bool = False, **kwargs) -> ResNet:
#     781     """Create a ResNet model.
#     782
#     783     Args:
#    (...)
#     789         ResNet model instance.
#     790     """
# --> 791     return build_model_with_cfg(ResNet, variant, pretrained, **kwargs)
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:457, in build_model_with_cfg(model_cls, variant, pretrained, pretrained_cfg, pretrained_cfg_overlay, model_cfg, feature_cfg, pretrained_strict, pretrained_filter_fn, cache_dir, kwargs_filter, **kwargs)
#     455 num_classes_pretrained = 0 if features else getattr(model, 'num_classes', kwargs.get('num_classes', 1000))
#     456 if pretrained:
# --> 457     load_pretrained(
#     458         model,
#     459         pretrained_cfg=pretrained_cfg,
#     460         num_classes=num_classes_pretrained,
#     461         in_chans=kwargs.get('in_chans', 3),
#     462         filter_fn=pretrained_filter_fn,
#     463         strict=pretrained_strict,
#     464         cache_dir=cache_dir,
#     465     )
#     467 # Wrap the model in a feature extraction module if enabled
#     468 if features:
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:226, in load_pretrained(model, pretrained_cfg, num_classes, in_chans, filter_fn, strict, cache_dir)
#     224             state_dict = load_state_dict_from_hf(*pretrained_loc, cache_dir=cache_dir)
#     225     else:
# --> 226         state_dict = load_state_dict_from_hf(pretrained_loc, weights_only=True, cache_dir=cache_dir)
#     227 elif load_from == 'local-dir':
#     228     _logger.info(f'Loading pretrained weights from local directory ({pretrained_loc})')
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:226, in load_state_dict_from_hf(model_id, filename, weights_only, cache_dir)
#     224 for safe_filename in _get_safe_alternatives(filename):
#     225     try:
# --> 226         cached_safe_file = hf_hub_download(
#     227             repo_id=hf_model_id,
#     228             filename=safe_filename,
#     229             revision=hf_revision,
#     230             cache_dir=cache_dir,
#     231         )
#     232         _logger.info(
#     233             f"[{model_id}] Safe alternative available for '{filename}' "
#     234             f"(as '{safe_filename}'). Loading weights using safetensors.")
#     235         return safetensors.torch.load_file(cached_safe_file, device="cpu")
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/huggingface_hub/utils/_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/huggingface_hub/file_download.py:1007, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     986     return _hf_hub_download_to_local_dir(
#     987         # Destination
#     988         local_dir=local_dir,
#    (...)
#    1004         dry_run=dry_run,
#    1005     )
#    1006 else:
# -> 1007     return _hf_hub_download_to_cache_dir(
#    1008         # Destination
#    1009         cache_dir=cache_dir,
#    1010         # File info
#    1011         repo_id=repo_id,
#    1012         filename=filename,
#    1013         repo_type=repo_type,
#    1014         revision=revision,
#    1015         # HTTP info
#    1016         endpoint=endpoint,
#    1017         etag_timeout=etag_timeout,
#    1018         headers=hf_headers,
#    1019         token=token,
#    1020         # Additional options
#    1021         local_files_only=local_files_only,
#    1022         force_download=force_download,
#    1023         tqdm_class=tqdm_class,
#    1024         dry_run=dry_run,
#    1025     )
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/huggingface_hub/file_download.py:1082, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1078             return pointer_path
#    1080 # Try to get metadata (etag, commit_hash, url, size) from the server.
#    1081 # If we can't, a HEAD request error is returned.
# -> 1082 (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = _get_metadata_or_catch_error(
#    1083     repo_id=repo_id,
#    1084     filename=filename,
#    1085     repo_type=repo_type,
#    1086     revision=revision,
#    1087     endpoint=endpoint,
#    1088     etag_timeout=etag_timeout,
#    1089     headers=headers,
#    1090     token=token,
#    1091     local_files_only=local_files_only,
#    1092     storage_folder=storage_folder,
#    1093     relative_filename=relative_filename,
#    1094 )
#    1096 # etag can be None for several reasons:
#    1097 # 1. we passed local_files_only.
#    1098 # 2. we don't have a connection
#    (...)
#    1104 # If the specified revision is a commit hash, look inside "snapshots".
#    1105 # If the specified revision is a branch or tag, look inside "refs".
#    1106 if head_call_error is not None:
#    1107     # Couldn't make a HEAD call => let's try to find a local file
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/huggingface_hub/file_download.py:1623, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1621 try:
#    1622     try:
# -> 1623         metadata = get_hf_file_metadata(
#    1624             url=url, timeout=etag_timeout, headers=headers, token=token, endpoint=endpoint
#    1625         )
#    1626     except RemoteEntryNotFoundError as http_error:
#    1627         if storage_folder is not None and relative_filename is not None:
#    1628             # Cache the non-existence of the file
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/huggingface_hub/utils/_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/huggingface_hub/file_download.py:1549, in get_hf_file_metadata(url, token, timeout, library_name, library_version, user_agent, headers, endpoint)
#    1546 hf_headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1548 # Retrieve metadata
# -> 1549 response = _httpx_follow_relative_redirects(method="HEAD", url=url, headers=hf_headers, timeout=timeout)
#    1550 hf_raise_for_status(response)
#    1552 # Return
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/huggingface_hub/file_download.py:284, in _httpx_follow_relative_redirects(method, url, **httpx_kwargs)
#     268 """Perform an HTTP request with backoff and follow relative redirects only.
#     269
#     270 This is useful to follow a redirection to a renamed repository without following redirection to a CDN.
#    (...)
#     280         Params to pass to `httpx.request`.
#     281 """
#     282 while True:
#     283     # Make the request
# --> 284     response = http_backoff(
#     285         method=method,
#     286         url=url,
#     287         **httpx_kwargs,
#     288         follow_redirects=False,
#     289         retry_on_exceptions=(),
#     290         retry_on_status_codes=(429,),
#     291     )
#     292     hf_raise_for_status(response)
#     294     # Check if response is a relative redirect
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/huggingface_hub/utils/_http.py:405, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     337 def http_backoff(
#     338     method: HTTP_METHOD_T,
#     339     url: str,
#    (...)
#     349     **kwargs,
#     350 ) -> httpx.Response:
#     351     """Wrapper around httpx to retry calls on an endpoint, with exponential backoff.
#     352
#     353     Endpoint call is retried on exceptions (ex: connection timeout, proxy error,...)
#    (...)
#     403     > issue on [Github](https://github.com/huggingface/huggingface_hub).
#     404     """
# --> 405     return next(
#     406         _http_backoff_base(
#     407             method=method,
#     408             url=url,
#     409             max_retries=max_retries,
#     410             base_wait_time=base_wait_time,
#     411             max_wait_time=max_wait_time,
#     412             retry_on_exceptions=retry_on_exceptions,
#     413             retry_on_status_codes=retry_on_status_codes,
#     414             stream=False,
#     415             **kwargs,
#     416         )
#     417     )
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/huggingface_hub/utils/_http.py:315, in _http_backoff_base(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, stream, **kwargs)
#     313             return
#     314 else:
# --> 315     response = client.request(method=method, url=url, **kwargs)
#     316     if not _should_retry(response):
#     317         yield response
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)
#     823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpcore/_sync/http_proxy.py:316, in TunnelHTTPConnection.handle_request(self, request)
#     310 kwargs = {
#     311     "ssl_context": ssl_context,
#     312     "server_hostname": self._remote_origin.host.decode("ascii"),
#     313     "timeout": timeout,
#     314 }
#     315 with Trace("start_tls", logger, request, kwargs) as trace:
# --> 316     stream = stream.start_tls(**kwargs)
#     317     trace.return_value = stream
#     319 # Determine if we should be using HTTP/1.1 or HTTP/2
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpcore/_sync/http11.py:376, in HTTP11UpgradeStream.start_tls(self, ssl_context, server_hostname, timeout)
#     370 def start_tls(
#     371     self,
#     372     ssl_context: ssl.SSLContext,
#     373     server_hostname: str | None = None,
#     374     timeout: float | None = None,
#     375 ) -> NetworkStream:
# --> 376     return self._stream.start_tls(ssl_context, server_hostname, timeout)
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpcore/_backends/sync.py:165, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     163     else:
#     164         self._sock.settimeout(timeout)
# --> 165         sock = ssl_context.wrap_socket(
#     166             self._sock, server_hostname=server_hostname
#     167         )
#     168 except Exception as exc:  # pragma: nocover
#     169     self.close()
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/ssl.py:501, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     495 def wrap_socket(self, sock, server_side=False,
#     496                 do_handshake_on_connect=True,
#     497                 suppress_ragged_eofs=True,
#     498                 server_hostname=None, session=None):
#     499     # SSLSocket class handles server_hostname encoding before it calls
#     500     # ctx._wrap_socket()
# --> 501     return self.sslsocket_class._create(
#     502         sock=sock,
#     503         server_side=server_side,
#     504         do_handshake_on_connect=do_handshake_on_connect,
#     505         suppress_ragged_eofs=suppress_ragged_eofs,
#     506         server_hostname=server_hostname,
#     507         context=self,
#     508         session=session
#     509     )
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/ssl.py:1074, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1071         if timeout == 0.0:
#    1072             # non-blocking
#    1073             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1074         self.do_handshake()
#    1075 except (OSError, ValueError):
#    1076     self.close()
#
# File ~/miniconda3/envs/nuplan/lib/python3.9/ssl.py:1343, in SSLSocket.do_handshake(self, block)
#    1341     if timeout == 0.0 and block:
#    1342         self.settimeout(None)
# -> 1343     self._sslobj.do_handshake()
#    1344 finally:
#    1345     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Launch training (command line - alternative)

# %% [markdown]
# A training experiment with the above same parameters can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_training.py \
#     experiment_name=raster_experiment \
#     py_func=train \
#     +training=training_raster_model \
#     scenario_builder=nuplan_mini \
#     scenario_filter.limit_total_scenarios=500 \
#     lightning.trainer.params.max_epochs=10 \
#     data_loader.params.batch_size=8 \
#     data_loader.params.num_workers=8
# ```

# %% [markdown]
# # Simulating a planner <a name="simulation"></a>

# %% [markdown]
# ## Open-loop simulation
# Open-loop simulation aims to evaluate the policy's capabilities to imitate the expert driver's behavior.<br />
# This is essentially done through log replay as the policy's predictions do not affect the state of the simulation.
#
# As the policy is not in full control of the vehicle, this type of simulation can only provide a high-level performance overview.
#
# ## Closed-loop simulation
# Conversely, in closed-loop simulation the policy's actions alter the state of the simulation which tries to closely approximate the real-world system.
#
# The simulation's feedback loop enables a more in-depth evaluation of the policy as compounding errors can cause future observations to significantly diverge from the ground truth.<br />
# This is important in measuring distribution shifts introduced due to lack of variance in training examples through pure imitation learning.
#
# Closed-loop simulation is further divided into two categories:
# * ego closed-loop simulation with agents replayed from log (open-loop, non reactive)
# * ego closed-loop simulation with agents controlled by a rule-based or learned policy (closed-loop, reactive)
#
# ## Measuring success
# Measuring the success of a planning task and comparing various planning policies is a complicated effort that involves defining metrics across different vertical dimensions and scenario categories.<br />
# These metrics include indicators such as vehicle dynamics, traffic rule violations, expert imitation, navigation success etc.<br />
# Overall, they aim to capture the policy's ability to control the autonomous vehicle safely yet efficiently without compromising the passenger's comfort.

# %% [markdown]
# ## Simulation parameters

# %% [markdown]
# ### Planners
#
# Change the planner model with `planner=X` where `X` is a config yaml defined in the table below.
#
# | Planner | Description | Config |
# | --- | --- | --- |
# | Simple Planner | Naive planner that only plans a straight path | `simple_planner` |
# | ML Planner | Learning-based planner trained using the nuPlan training framework (see previous section) | `ml_planner` |

# %% [markdown]
# ## Prepare the simulation config

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Select the planner and simulation challenge
PLANNER = 'simple_planner'  # [simple_planner, ml_planner]
CHALLENGE = 'open_loop_boxes'  # [open_loop_boxes, closed_loop_nonreactive_agents, closed_loop_reactive_agents]
DATASET_PARAMS = [
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter=all_scenarios',  # initially select all scenarios in the database
    'scenario_filter.scenario_types=[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]',  # select scenario types
    'scenario_filter.num_scenarios_per_type=2',  # use 10 scenarios per scenario type
]

# Name of the experiment
EXPERIMENT = 'simulation_simple_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    f'planner={PLANNER}',
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])
# Out:
# /home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'default_simulation': Defaults list is missing `_self_`. See https://hydra.cc/docs/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Launch simulation (within the notebook)

# %%
from nuplan.planning.script.run_simulation import main as main_simulation

# Run the simulation loop (real-time visualization not yet supported, see next section for visualization)
main_simulation(cfg)

# Simple simulation folder for visualization in nuBoard
simple_simulation_folder = cfg.output_dir
# Out:
# Global seed set to 0
# 2025-11-19 00:25:50,629 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2025-11-19 00:25:50,832 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2025-11-19 00:25:51,003 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2025-11-19 00:25:51,004 WARNING {/home/gcjms/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2025-11-19 00:25:52,968 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2025-11-19 00:25:56,799	INFO worker.py:2012 -- Started a local Ray instance.
# 2025-11-19 00:26:02,540 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2025-11-19 00:26:02,540 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 16
# Number of GPUs per node: 1
# Number of threads across all nodes: 16
# 2025-11-19 00:26:02,540 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2025-11-19 00:26:02,541 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2025-11-19 00:26:02,541 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_simple_experiment/open_loop_boxes/2025.11.19.00.25.50
#
# 2025-11-19 00:26:02,548 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2025-11-19 00:26:02,548 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2025-11-19 00:26:02,549 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2025-11-19 00:26:02,549 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2025-11-19 00:26:02,549 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2025-11-19 00:26:02,549 INFO {/home/gcjms/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2025-11-19 00:26:02,550 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2025-11-19 00:26:02,572 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2025-11-19 00:26:02,573 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2025-11-19 00:26:02,574 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# Ray objects:  25%|██▌       | 4/16 [00:15<00:32,  2.73s/it](pid=gcs_server) [2025-11-19 00:26:23,361 E 49965 49965] (gcs_server) gcs_server.cc:302: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# Ray objects:  31%|███▏      | 5/16 [00:21<00:43,  3.93s/it](raylet) [2025-11-19 00:26:26,797 E 50136 50136] (raylet) main.cc:975: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (wrapped_fn pid=50252) [2025-11-19 00:26:31,621 E 50252 50610] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2025-11-19 00:26:32,549 E 44949 50240] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# Ray objects: 100%|██████████| 16/16 [04:17<00:00, 16.07s/it]
# 2025-11-19 00:30:19,829 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2025-11-19 00:30:19,879 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2025-11-19 00:30:19,879 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 7 scenarios...
# 2025-11-19 00:30:22,028 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:133}  Building simulations...DONE!
# 2025-11-19 00:30:22,028 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/run_simulation.py:78}  Running simulation...
# 2025-11-19 00:30:22,028 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/utils.py:138}  Executing runners...
# 2025-11-19 00:30:22,028 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 7 simulations using RayDistributed!
# Ray objects: 100%|██████████| 7/7 [02:01<00:00, 17.39s/it]
# 2025-11-19 00:32:23,809 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 7
# 2025-11-19 00:32:23,810 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 0
# 2025-11-19 00:32:23,810 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/utils.py:147}  Finished executing runners!
# 2025-11-19 00:32:23,862 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/utils.py:74}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_simple_experiment/open_loop_boxes/2025.11.19.00.25.50/runner_report.parquet
# 2025-11-19 00:32:23,862 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:06:44 [HH:MM:SS]
# 2025-11-19 00:32:23,938 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:79}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2025-11-19 00:32:24,026 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Running metric aggregator: open_loop_boxes_weighted_average
# 2025-11-19 00:32:24,041 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:69}  Metric aggregator: 00:00:00 [HH:MM:SS]
# Rendering histograms: 100%|██████████| 6/6 [00:01<00:00,  3.54it/s]
# 2025-11-19 00:32:27,753 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:03 [HH:MM:SS]
# 2025-11-19 00:32:27,753 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Finished running simulation!

# %% [markdown]
# ## Launch simulation (command line - alternative)

# %% [markdown]
# A simulation experiment can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_simulation.py \
#     +simulation=open_loop_boxes \
#     planner=simple_planner \
#     scenario_builder=nuplan_mini \
#     scenario_filter=all_scenarios \
#     scenario_filter.scenario_types="[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]" \
#     scenario_filter.num_scenarios_per_type=10 \
# ```

# %% [markdown]
# ## Simulate a trained ML planner for comparison
#
# Using the same simulation settings as before, we can simulate a pretrained ML planner and compare the two.
#
# In this example you can take the model you trained earlier.

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Get the checkpoint of the trained model
last_experiment = sorted(os.listdir(LOG_DIR))[-1]
train_experiment_dir = sorted(LOG_DIR.iterdir())[-1]
checkpoint = sorted((train_experiment_dir / 'checkpoints').iterdir())[-1]

MODEL_PATH = str(checkpoint).replace("=", "\=")

# Name of the experiment
EXPERIMENT = 'simulation_raster_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    'planner=ml_planner',
    'model=raster_model',
    'planner.ml_planner.model_config=${model}',  # hydra notation to select model config
    f'planner.ml_planner.checkpoint_path={MODEL_PATH}',  # this path can be replaced by the checkpoint of the model trained in the previous section
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# Run the simulation loop
main_simulation(cfg)

# ML_planner simulation folder for visualization in nuBoard (next section)
ml_planner_simulation_folder = cfg.output_dir
# Out:
# /home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'default_simulation': Defaults list is missing `_self_`. See https://hydra.cc/docs/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# Global seed set to 0
# 2025-11-19 00:32:32,845 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2025-11-19 00:32:32,878 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2025-11-19 00:32:33,049 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2025-11-19 00:32:33,049 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2025-11-19 00:32:33,051 WARNING {/home/gcjms/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2025-11-19 00:32:33,051 WARNING {/home/gcjms/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2025-11-19 00:32:34,768 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2025-11-19 00:32:34,768 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2025-11-19 00:32:38,003	INFO worker.py:2012 -- Started a local Ray instance.
# 2025-11-19 00:32:45,253 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2025-11-19 00:32:45,253 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2025-11-19 00:32:45,254 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 16
# Number of GPUs per node: 1
# Number of threads across all nodes: 16
# 2025-11-19 00:32:45,254 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 16
# Number of GPUs per node: 1
# Number of threads across all nodes: 16
# 2025-11-19 00:32:45,254 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2025-11-19 00:32:45,254 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2025-11-19 00:32:45,254 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2025-11-19 00:32:45,254 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2025-11-19 00:32:45,255 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_raster_experiment/open_loop_boxes/2025.11.19.00.32.32
#
# 2025-11-19 00:32:45,255 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_raster_experiment/open_loop_boxes/2025.11.19.00.32.32
#
# 2025-11-19 00:32:45,258 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2025-11-19 00:32:45,258 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2025-11-19 00:32:45,258 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2025-11-19 00:32:45,258 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2025-11-19 00:32:45,259 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2025-11-19 00:32:45,259 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2025-11-19 00:32:45,259 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2025-11-19 00:32:45,259 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2025-11-19 00:32:45,259 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2025-11-19 00:32:45,259 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2025-11-19 00:32:45,259 INFO {/home/gcjms/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2025-11-19 00:32:45,259 INFO {/home/gcjms/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2025-11-19 00:32:45,259 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2025-11-19 00:32:45,259 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2025-11-19 00:32:45,284 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2025-11-19 00:32:45,284 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2025-11-19 00:32:45,284 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2025-11-19 00:32:45,284 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2025-11-19 00:32:45,286 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2025-11-19 00:32:45,286 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# Ray objects:  31%|███▏      | 5/16 [00:15<00:29,  2.71s/it](pid=gcs_server) [2025-11-19 00:33:05,150 E 53297 53297] (gcs_server) gcs_server.cc:302: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2025-11-19 00:33:07,972 E 53468 53468] (raylet) main.cc:975: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (wrapped_fn pid=53571) [2025-11-19 00:33:13,721 E 53571 53877] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2025-11-19 00:33:15,260 E 44949 53568] core_worker_process.cc:825: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# Ray objects: 100%|██████████| 16/16 [03:55<00:00, 14.72s/it]
# 2025-11-19 00:36:40,936 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2025-11-19 00:36:40,936 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2025-11-19 00:36:40,973 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2025-11-19 00:36:40,973 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2025-11-19 00:36:40,973 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 7 scenarios...
# 2025-11-19 00:36:40,973 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 7 scenarios...
# 2025-11-19 00:36:40,975 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-19 00:36:40,975 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-19 00:36:41,334 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# 2025-11-19 00:36:41,334 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# 2025-11-19 00:36:41,938 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1025}  HTTP Request: HEAD https://huggingface.co/timm/resnet50.a1_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2025-11-19 00:36:41,938 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1025}  HTTP Request: HEAD https://huggingface.co/timm/resnet50.a1_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2025-11-19 00:36:41,944 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:232}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-11-19 00:36:41,944 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:232}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-11-19 00:36:42,019 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:253}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2025-11-19 00:36:42,019 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:253}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2025-11-19 00:36:42,111 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2025-11-19 00:36:42,111 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# /home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/pytorch_lightning/utilities/cloud_io.py:33: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=map_location)
# 2025-11-19 00:36:44,730 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-19 00:36:44,730 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-19 00:36:45,049 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# 2025-11-19 00:36:45,049 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# 2025-11-19 00:36:45,384 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1025}  HTTP Request: HEAD https://huggingface.co/timm/resnet50.a1_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2025-11-19 00:36:45,384 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1025}  HTTP Request: HEAD https://huggingface.co/timm/resnet50.a1_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2025-11-19 00:36:45,385 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:232}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-11-19 00:36:45,385 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:232}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-11-19 00:36:45,393 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:253}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2025-11-19 00:36:45,393 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:253}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2025-11-19 00:36:45,426 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2025-11-19 00:36:45,426 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2025-11-19 00:36:46,643 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-19 00:36:46,643 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-19 00:36:46,044 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# 2025-11-19 00:36:46,044 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# 2025-11-19 00:36:46,367 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1025}  HTTP Request: HEAD https://huggingface.co/timm/resnet50.a1_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2025-11-19 00:36:46,367 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1025}  HTTP Request: HEAD https://huggingface.co/timm/resnet50.a1_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2025-11-19 00:36:46,369 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:232}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-11-19 00:36:46,369 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:232}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-11-19 00:36:46,377 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:253}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2025-11-19 00:36:46,377 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:253}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2025-11-19 00:36:46,415 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2025-11-19 00:36:46,415 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2025-11-19 00:36:47,052 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-19 00:36:47,052 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-19 00:36:47,277 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# 2025-11-19 00:36:47,277 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# 2025-11-19 00:36:47,600 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1025}  HTTP Request: HEAD https://huggingface.co/timm/resnet50.a1_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2025-11-19 00:36:47,600 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1025}  HTTP Request: HEAD https://huggingface.co/timm/resnet50.a1_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2025-11-19 00:36:47,601 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:232}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-11-19 00:36:47,601 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:232}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-11-19 00:36:47,609 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:253}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2025-11-19 00:36:47,609 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:253}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2025-11-19 00:36:47,647 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2025-11-19 00:36:47,647 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2025-11-19 00:36:48,845 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-19 00:36:48,845 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-19 00:36:49,082 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# 2025-11-19 00:36:49,082 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# 2025-11-19 00:36:49,433 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1025}  HTTP Request: HEAD https://huggingface.co/timm/resnet50.a1_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2025-11-19 00:36:49,433 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1025}  HTTP Request: HEAD https://huggingface.co/timm/resnet50.a1_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2025-11-19 00:36:49,434 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:232}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-11-19 00:36:49,434 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:232}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-11-19 00:36:49,442 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:253}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2025-11-19 00:36:49,442 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:253}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2025-11-19 00:36:49,470 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2025-11-19 00:36:49,470 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2025-11-19 00:36:50,009 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-19 00:36:50,009 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-19 00:36:50,265 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# 2025-11-19 00:36:50,265 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# 2025-11-19 00:36:50,608 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1025}  HTTP Request: HEAD https://huggingface.co/timm/resnet50.a1_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2025-11-19 00:36:50,608 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1025}  HTTP Request: HEAD https://huggingface.co/timm/resnet50.a1_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2025-11-19 00:36:50,610 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:232}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-11-19 00:36:50,610 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:232}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-11-19 00:36:50,619 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:253}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2025-11-19 00:36:50,619 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:253}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2025-11-19 00:36:50,653 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2025-11-19 00:36:50,653 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2025-11-19 00:36:51,615 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-19 00:36:51,615 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2025-11-19 00:36:51,837 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# 2025-11-19 00:36:51,837 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:217}  Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# 2025-11-19 00:36:52,171 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1025}  HTTP Request: HEAD https://huggingface.co/timm/resnet50.a1_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2025-11-19 00:36:52,171 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/httpx/_client.py:1025}  HTTP Request: HEAD https://huggingface.co/timm/resnet50.a1_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2025-11-19 00:36:52,173 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:232}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-11-19 00:36:52,173 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_hub.py:232}  [timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-11-19 00:36:52,181 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:253}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2025-11-19 00:36:52,181 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/timm/models/_builder.py:253}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2025-11-19 00:36:52,212 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2025-11-19 00:36:52,212 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2025-11-19 00:36:52,787 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:133}  Building simulations...DONE!
# 2025-11-19 00:36:52,787 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:133}  Building simulations...DONE!
# 2025-11-19 00:36:52,788 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/run_simulation.py:78}  Running simulation...
# 2025-11-19 00:36:52,788 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/run_simulation.py:78}  Running simulation...
# 2025-11-19 00:36:52,788 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/utils.py:138}  Executing runners...
# 2025-11-19 00:36:52,788 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/utils.py:138}  Executing runners...
# 2025-11-19 00:36:52,788 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 7 simulations using RayDistributed!
# 2025-11-19 00:36:52,788 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 7 simulations using RayDistributed!
# (raylet) Task wrapped_fn failed. There are infinite retries remaining, so the task will be retried. Error: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.17.83.201, ID: 2a6305a7902fbbda2ae7f23e975e9d5e29261a0c428a7c01f5d569b0) where the lease (actor ID: NIL_IDlease ID: 3a00000001000000ffffffffffffffffffffffffffffffffffffffffffffffff, name=wrapped_fn, pid=53569, memory used=0.18GB) was running was 7.12GB / 7.44GB (0.956937), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: dd285f9ad03211177c22f11686eb1af96ab9554bcf413c254ec9ee6a) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.17.83.201`. To see the logs of the worker, use `ray logs worker-dd285f9ad03211177c22f11686eb1af96ab9554bcf413c254ec9ee6a*out -ip 172.17.83.201. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 44949	2.48	/home/gcjms/miniconda3/envs/nuplan/bin/python -m ipykernel_launcher --f=/run/user/1000/jupyter/runti...
# 41631	0.64	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node --dns-result-order=ipv4...
# 53574	0.18	ray::wrapped_fn
# 53570	0.18	ray::wrapped_fn
# 53580	0.18	ray::wrapped_fn
# 53569	0.18	ray::wrapped_fn
# 53581	0.17	ray::IDLE
# 53577	0.17	ray::IDLE
# 53572	0.17	ray::IDLE
# 53611	0.17	ray::IDLE
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# Ray objects:   0%|          | 0/7 [00:00<?, ?it/s]
# (raylet) Task wrapped_fn failed. There are infinite retries remaining, so the task will be retried. Error: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.17.83.201, ID: 2a6305a7902fbbda2ae7f23e975e9d5e29261a0c428a7c01f5d569b0) where the lease (actor ID: NIL_IDlease ID: 3c00000001000000ffffffffffffffffffffffffffffffffffffffffffffffff, name=wrapped_fn, pid=53577, memory used=0.17GB) was running was 7.12GB / 7.44GB (0.955908), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: b03fcc3771b56ed00a5b9193ee219adfa05e39815768055b3fef8463) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.17.83.201`. To see the logs of the worker, use `ray logs worker-b03fcc3771b56ed00a5b9193ee219adfa05e39815768055b3fef8463*out -ip 172.17.83.201. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 44949	2.60	/home/gcjms/miniconda3/envs/nuplan/bin/python -m ipykernel_launcher --f=/run/user/1000/jupyter/runti...
# 41631	0.64	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node --dns-result-order=ipv4...
# 53574	0.18	ray::wrapped_fn
# 53570	0.18	ray::wrapped_fn
# 53580	0.18	ray::wrapped_fn
# 53577	0.17	ray::wrapped_fn
# 53581	0.17	ray::IDLE
# 53576	0.17	ray::wrapped_fn
# 53572	0.17	ray::IDLE
# 53611	0.17	ray::IDLE
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) Task wrapped_fn failed. There are infinite retries remaining, so the task will be retried. Error: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.17.83.201, ID: 2a6305a7902fbbda2ae7f23e975e9d5e29261a0c428a7c01f5d569b0) where the lease (actor ID: NIL_IDlease ID: 3d00000001000000ffffffffffffffffffffffffffffffffffffffffffffffff, name=wrapped_fn, pid=53581, memory used=0.18GB) was running was 7.09GB / 7.44GB (0.952781), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: 94c8b260f9f6058516fddd205b56d6e49bcecc745b1eadfcfd6a0b10) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.17.83.201`. To see the logs of the worker, use `ray logs worker-94c8b260f9f6058516fddd205b56d6e49bcecc745b1eadfcfd6a0b10*out -ip 172.17.83.201. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 44949	2.68	/home/gcjms/miniconda3/envs/nuplan/bin/python -m ipykernel_launcher --f=/run/user/1000/jupyter/runti...
# 41631	0.64	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node --dns-result-order=ipv4...
# 53570	0.20	ray::wrapped_fn
# 53574	0.19	ray::wrapped_fn
# 53576	0.19	ray::wrapped_fn
# 53580	0.19	ray::wrapped_fn
# 53581	0.18	ray::wrapped_fn
# 53572	0.17	ray::IDLE
# 53611	0.17	ray::IDLE
# 53579	0.17	ray::IDLE
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) Task wrapped_fn failed. There are infinite retries remaining, so the task will be retried. Error: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.17.83.201, ID: 2a6305a7902fbbda2ae7f23e975e9d5e29261a0c428a7c01f5d569b0) where the lease (actor ID: NIL_IDlease ID: 4000000001000000ffffffffffffffffffffffffffffffffffffffffffffffff, name=wrapped_fn, pid=53572, memory used=0.18GB) was running was 7.12GB / 7.44GB (0.956535), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: 27bb3956f5ea1771514cc8ded9a4df3de408be2d8d1cfecf52935cf1) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.17.83.201`. To see the logs of the worker, use `ray logs worker-27bb3956f5ea1771514cc8ded9a4df3de408be2d8d1cfecf52935cf1*out -ip 172.17.83.201. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 44949	2.68	/home/gcjms/miniconda3/envs/nuplan/bin/python -m ipykernel_launcher --f=/run/user/1000/jupyter/runti...
# 41631	0.64	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node --dns-result-order=ipv4...
# 53580	0.26	ray::wrapped_fn
# 53574	0.26	ray::wrapped_fn
# 53570	0.25	ray::wrapped_fn
# 53576	0.22	ray::wrapped_fn
# 53611	0.19	ray::wrapped_fn
# 53579	0.19	ray::wrapped_fn
# 53572	0.18	ray::wrapped_fn
# 53575	0.17	ray::IDLE
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) Task wrapped_fn failed. There are infinite retries remaining, so the task will be retried. Error: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.17.83.201, ID: 2a6305a7902fbbda2ae7f23e975e9d5e29261a0c428a7c01f5d569b0) where the lease (actor ID: NIL_IDlease ID: 3f00000001000000ffffffffffffffffffffffffffffffffffffffffffffffff, name=wrapped_fn, pid=53611, memory used=0.20GB) was running was 7.09GB / 7.44GB (0.953016), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: d8abe9d7ab58d2f6a94f1e1880cde541f49b478a00f9d095f7ad979d) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.17.83.201`. To see the logs of the worker, use `ray logs worker-d8abe9d7ab58d2f6a94f1e1880cde541f49b478a00f9d095f7ad979d*out -ip 172.17.83.201. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 44949	2.62	/home/gcjms/miniconda3/envs/nuplan/bin/python -m ipykernel_launcher --f=/run/user/1000/jupyter/runti...
# 41631	0.65	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node --dns-result-order=ipv4...
# 53580	0.31	ray::wrapped_fn
# 53574	0.31	ray::wrapped_fn
# 53570	0.30	ray::wrapped_fn
# 53576	0.27	ray::wrapped_fn
# 53611	0.20	ray::wrapped_fn
# 53579	0.20	ray::wrapped_fn
# 53575	0.17	ray::IDLE
# 53571	0.17	ray::IDLE
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) Task wrapped_fn failed. There are infinite retries remaining, so the task will be retried. Error: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.17.83.201, ID: 2a6305a7902fbbda2ae7f23e975e9d5e29261a0c428a7c01f5d569b0) where the lease (actor ID: NIL_IDlease ID: 3e00000001000000ffffffffffffffffffffffffffffffffffffffffffffffff, name=wrapped_fn, pid=53579, memory used=0.25GB) was running was 7.09GB / 7.44GB (0.953021), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: 84da1eaa705b3dd153452b2301563c49d75629423909141f638f57bd) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.17.83.201`. To see the logs of the worker, use `ray logs worker-84da1eaa705b3dd153452b2301563c49d75629423909141f638f57bd*out -ip 172.17.83.201. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 44949	2.54	/home/gcjms/miniconda3/envs/nuplan/bin/python -m ipykernel_launcher --f=/run/user/1000/jupyter/runti...
# 41631	0.65	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node --dns-result-order=ipv4...
# 53574	0.35	ray::wrapped_fn
# 53576	0.35	ray::wrapped_fn
# 53570	0.34	ray::wrapped_fn
# 53580	0.34	ray::wrapped_fn
# 53579	0.25	ray::wrapped_fn
# 53575	0.17	ray::IDLE
# 53571	0.17	ray::IDLE
# 53573	0.17	ray::IDLE
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) Task wrapped_fn failed. There are infinite retries remaining, so the task will be retried. Error: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.17.83.201, ID: 2a6305a7902fbbda2ae7f23e975e9d5e29261a0c428a7c01f5d569b0) where the lease (actor ID: NIL_IDlease ID: 4300000001000000ffffffffffffffffffffffffffffffffffffffffffffffff, name=wrapped_fn, pid=53573, memory used=0.18GB) was running was 7.07GB / 7.44GB (0.950139), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: 5eb8712b5dee7b1d84dbbc64d248ed38824f1d8acc29126d8ad44f83) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.17.83.201`. To see the logs of the worker, use `ray logs worker-5eb8712b5dee7b1d84dbbc64d248ed38824f1d8acc29126d8ad44f83*out -ip 172.17.83.201. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 44949	2.30	/home/gcjms/miniconda3/envs/nuplan/bin/python -m ipykernel_launcher --f=/run/user/1000/jupyter/runti...
# 41631	0.62	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node --dns-result-order=ipv4...
# 53580	0.50	ray::wrapped_fn
# 53576	0.49	ray::wrapped_fn
# 53570	0.48	ray::wrapped_fn
# 53574	0.44	ray::wrapped_fn
# 53571	0.29	ray::wrapped_fn
# 53573	0.18	ray::wrapped_fn
# 53578	0.17	ray::IDLE
# 53619	0.17	ray::IDLE
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero. [repeated 2x across cluster]
# (raylet) Task wrapped_fn failed. There are infinite retries remaining, so the task will be retried. Error: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.17.83.201, ID: 2a6305a7902fbbda2ae7f23e975e9d5e29261a0c428a7c01f5d569b0) where the lease (actor ID: NIL_IDlease ID: 4100000001000000ffffffffffffffffffffffffffffffffffffffffffffffff, name=wrapped_fn, pid=53571, memory used=0.32GB) was running was 7.13GB / 7.44GB (0.958467), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: 38881bde8a859cc808cf80a1d8dd14c777af55448f505aa65ae93f12) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.17.83.201`. To see the logs of the worker, use `ray logs worker-38881bde8a859cc808cf80a1d8dd14c777af55448f505aa65ae93f12*out -ip 172.17.83.201. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 44949	1.88	/home/gcjms/miniconda3/envs/nuplan/bin/python -m ipykernel_launcher --f=/run/user/1000/jupyter/runti...
# 53580	0.62	ray::wrapped_fn
# 41631	0.61	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node --dns-result-order=ipv4...
# 53570	0.61	ray::wrapped_fn
# 53576	0.61	ray::wrapped_fn
# 53574	0.54	ray::wrapped_fn
# 53571	0.32	ray::wrapped_fn
# 53578	0.17	ray::IDLE
# 53619	0.17	ray::IDLE
# 53640	0.17	ray::IDLE
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) Task wrapped_fn failed. There are infinite retries remaining, so the task will be retried. Error: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.17.83.201, ID: 2a6305a7902fbbda2ae7f23e975e9d5e29261a0c428a7c01f5d569b0) where the lease (actor ID: NIL_IDlease ID: 4600000001000000ffffffffffffffffffffffffffffffffffffffffffffffff, name=wrapped_fn, pid=53578, memory used=0.20GB) was running was 7.08GB / 7.44GB (0.950705), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: d1421b34739a2d1a3a0de5c323e5f1ba1cfe01a78714b98b23e4c845) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.17.83.201`. To see the logs of the worker, use `ray logs worker-d1421b34739a2d1a3a0de5c323e5f1ba1cfe01a78714b98b23e4c845*out -ip 172.17.83.201. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 44949	1.71	/home/gcjms/miniconda3/envs/nuplan/bin/python -m ipykernel_launcher --f=/run/user/1000/jupyter/runti...
# 53580	0.61	ray::wrapped_fn
# 53570	0.60	ray::wrapped_fn
# 53576	0.60	ray::wrapped_fn
# 53574	0.60	ray::wrapped_fn
# 41631	0.59	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node --dns-result-order=ipv4...
# 53640	0.35	ray::wrapped_fn
# 53578	0.20	ray::wrapped_fn
# 53619	0.19	ray::wrapped_fn
# 53297	0.11	/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/ray/core/src/ray/gcs/gcs_server --log...
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) Task wrapped_fn failed. There are infinite retries remaining, so the task will be retried. Error: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.17.83.201, ID: 2a6305a7902fbbda2ae7f23e975e9d5e29261a0c428a7c01f5d569b0) where the lease (actor ID: NIL_IDlease ID: 4500000001000000ffffffffffffffffffffffffffffffffffffffffffffffff, name=wrapped_fn, pid=53619, memory used=0.29GB) was running was 7.08GB / 7.44GB (0.951486), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: 188c9f76e77939a9b3be7c94b7d0c7dc91fe08c65fcdac96ca5bc30c) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.17.83.201`. To see the logs of the worker, use `ray logs worker-188c9f76e77939a9b3be7c94b7d0c7dc91fe08c65fcdac96ca5bc30c*out -ip 172.17.83.201. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 44949	1.71	/home/gcjms/miniconda3/envs/nuplan/bin/python -m ipykernel_launcher --f=/run/user/1000/jupyter/runti...
# 53580	0.63	ray::wrapped_fn
# 53570	0.62	ray::wrapped_fn
# 53576	0.62	ray::wrapped_fn
# 53574	0.62	ray::wrapped_fn
# 41631	0.59	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node --dns-result-order=ipv4...
# 53640	0.37	ray::wrapped_fn
# 53619	0.29	ray::wrapped_fn
# 53297	0.11	/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/ray/core/src/ray/gcs/gcs_server --log...
# 41510	0.08	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node /home/gcjms/.vscode-ser...
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))]
# ...
# (wrapped_fn pid=53580) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 4x across cluster]
# (wrapped_fn pid=53580)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 4x across cluster]
# (wrapped_fn pid=53580) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 7x across cluster]
# (wrapped_fn pid=53580)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 7x across cluster]
# (raylet) Task wrapped_fn failed. There are infinite retries remaining, so the task will be retried. Error: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.17.83.201, ID: 2a6305a7902fbbda2ae7f23e975e9d5e29261a0c428a7c01f5d569b0) where the lease (actor ID: NIL_IDlease ID: 5000000001000000ffffffffffffffffffffffffffffffffffffffffffffffff, name=wrapped_fn, pid=56825, memory used=0.12GB) was running was 7.07GB / 7.44GB (0.950424), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: 4ee40a4dca883baa4025e30d3478ab225460fa50e0ddf4a2f392a4b8) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.17.83.201`. To see the logs of the worker, use `ray logs worker-4ee40a4dca883baa4025e30d3478ab225460fa50e0ddf4a2f392a4b8*out -ip 172.17.83.201. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 44949	1.70	/home/gcjms/miniconda3/envs/nuplan/bin/python -m ipykernel_launcher --f=/run/user/1000/jupyter/runti...
# 53570	0.92	ray::wrapped_fn
# 53580	0.66	ray::wrapped_fn
# 53574	0.65	ray::wrapped_fn
# 53576	0.65	ray::wrapped_fn
# 41631	0.59	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node --dns-result-order=ipv4...
# 56545	0.47	ray::wrapped_fn
# 56824	0.21	ray::wrapped_fn
# 56825	0.12	ray::IDLE
# 41510	0.08	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node /home/gcjms/.vscode-ser...
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) Task wrapped_fn failed. There are infinite retries remaining, so the task will be retried. Error: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.17.83.201, ID: 2a6305a7902fbbda2ae7f23e975e9d5e29261a0c428a7c01f5d569b0) where the lease (actor ID: NIL_IDlease ID: 4f00000001000000ffffffffffffffffffffffffffffffffffffffffffffffff, name=wrapped_fn, pid=56824, memory used=0.31GB) was running was 7.08GB / 7.44GB (0.950644), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: 28b9923b3793e77021792aae18682543d17c6659fafdbc78eb5d646b) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.17.83.201`. To see the logs of the worker, use `ray logs worker-28b9923b3793e77021792aae18682543d17c6659fafdbc78eb5d646b*out -ip 172.17.83.201. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 44949	1.70	/home/gcjms/miniconda3/envs/nuplan/bin/python -m ipykernel_launcher --f=/run/user/1000/jupyter/runti...
# 53570	0.92	ray::wrapped_fn
# 53576	0.74	ray::wrapped_fn
# 53580	0.66	ray::wrapped_fn
# 53574	0.65	ray::wrapped_fn
# 41631	0.59	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node --dns-result-order=ipv4...
# 56545	0.38	ray::wrapped_fn
# 56824	0.31	ray::wrapped_fn
# 41510	0.09	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node /home/gcjms/.vscode-ser...
# 53297	0.03	/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/ray/core/src/ray/gcs/gcs_server --log...
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (wrapped_fn pid=53580) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 12x across cluster]
# (wrapped_fn pid=53580)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 12x across cluster]
# (raylet) Task wrapped_fn failed. There are infinite retries remaining, so the task will be retried. Error: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.17.83.201, ID: 2a6305a7902fbbda2ae7f23e975e9d5e29261a0c428a7c01f5d569b0) where the lease (actor ID: NIL_IDlease ID: 4e00000001000000ffffffffffffffffffffffffffffffffffffffffffffffff, name=wrapped_fn, pid=56545, memory used=0.61GB) was running was 7.08GB / 7.44GB (0.950589), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: 802e3d87fd440ed142b4bca3ced967ce112bf5b91d462bf4cc69b658) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.17.83.201`. To see the logs of the worker, use `ray logs worker-802e3d87fd440ed142b4bca3ced967ce112bf5b91d462bf4cc69b658*out -ip 172.17.83.201. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 44949	1.70	/home/gcjms/miniconda3/envs/nuplan/bin/python -m ipykernel_launcher --f=/run/user/1000/jupyter/runti...
# 53570	0.93	ray::wrapped_fn
# 53576	0.85	ray::wrapped_fn
# 53580	0.67	ray::wrapped_fn
# 53574	0.65	ray::wrapped_fn
# 56545	0.61	ray::wrapped_fn
# 41631	0.59	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node --dns-result-order=ipv4...
# 41510	0.09	/home/gcjms/.vscode-server/bin/cb1933bbc38d329b3595673a600fab5c7368f0a7/node /home/gcjms/.vscode-ser...
# 53297	0.03	/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/ray/core/src/ray/gcs/gcs_server --log...
# 53468	0.02	/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/ray/core/src/ray/raylet/raylet --rayl...
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# Ray objects:  43%|████▎     | 3/7 [03:22<03:11, 47.95s/it] (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 39x across cluster]
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 39x across cluster]
# Ray objects:  57%|█████▋    | 4/7 [03:30<01:35, 31.97s/it](wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 21x across cluster]
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 21x across cluster]
# (raylet) [2025-11-19 00:40:37,953 E 53468 53468] (raylet) node_manager.cc:3252: 3 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 2a6305a7902fbbda2ae7f23e975e9d5e29261a0c428a7c01f5d569b0, IP: 172.17.83.201) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.17.83.201`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 13x across cluster]
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 13x across cluster]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 63x across cluster]
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 63x across cluster]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 51x across cluster]
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 51x across cluster]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 24x across cluster]
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 24x across cluster]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 15x across cluster]
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 15x across cluster]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 15x across cluster]
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 15x across cluster]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 12x across cluster]
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 12x across cluster]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 13x across cluster]
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 13x across cluster]
# (wrapped_fn pid=53580) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 13x across cluster]
# (wrapped_fn pid=53580)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 13x across cluster]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 14x across cluster]
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 14x across cluster]
# (wrapped_fn pid=53574) /home/gcjms/nuplan-devkit/nuplan/common/maps/nuplan_map/utils.py:413: RuntimeWarning: invalid value encountered in cast [repeated 5x across cluster]
# (wrapped_fn pid=53574)   return elements.iloc[np.where(elements[column_label].to_numpy().astype(int) == int(desired_value))] [repeated 5x across cluster]
# Ray objects: 100%|██████████| 7/7 [05:59<00:00, 51.40s/it]
# 2025-11-19 00:42:54,941 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 7
# 2025-11-19 00:42:54,941 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 7
# 2025-11-19 00:42:54,948 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 0
# 2025-11-19 00:42:54,948 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 0
# 2025-11-19 00:42:54,948 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/utils.py:147}  Finished executing runners!
# 2025-11-19 00:42:54,948 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/utils.py:147}  Finished executing runners!
# 2025-11-19 00:42:55,058 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/utils.py:74}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_raster_experiment/open_loop_boxes/2025.11.19.00.32.32/runner_report.parquet
# 2025-11-19 00:42:55,058 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/utils.py:74}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_raster_experiment/open_loop_boxes/2025.11.19.00.32.32/runner_report.parquet
# 2025-11-19 00:42:55,061 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:10:40 [HH:MM:SS]
# 2025-11-19 00:42:55,061 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:10:40 [HH:MM:SS]
# 2025-11-19 00:42:55,173 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:79}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2025-11-19 00:42:55,173 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:79}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2025-11-19 00:42:55,306 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Running metric aggregator: open_loop_boxes_weighted_average
# 2025-11-19 00:42:55,306 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Running metric aggregator: open_loop_boxes_weighted_average
# 2025-11-19 00:42:55,329 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:69}  Metric aggregator: 00:00:00 [HH:MM:SS]
# 2025-11-19 00:42:55,329 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:69}  Metric aggregator: 00:00:00 [HH:MM:SS]
# Rendering histograms: 100%|██████████| 6/6 [00:02<00:00,  2.81it/s]
# 2025-11-19 00:42:59,620 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:04 [HH:MM:SS]
# 2025-11-19 00:42:59,620 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:04 [HH:MM:SS]
# 2025-11-19 00:42:59,621 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Finished running simulation!
# 2025-11-19 00:42:59,621 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Finished running simulation!

# %%
print("kernel 还活着")
# Out:
# kernel 还活着

# %% [markdown]
# # Visualizing metrics and scenarios <a name="dashboard"></a>

# %% [markdown]
# ## nuBoard summary
#
# Having trained and simulated planners across various scenarios and driving behaviors, it's time to evaluate them:
# * quantitatively, through common and scenario dependent metrics
# * qualitatively, through visualization of scenario progression
#
# ### nuBoard tabs
# To achieve that, nuBoard has 3 core evaluation tabs:
# 1. Overview - Scalar metrics summary of common and scenario metrics across the following categories:
#     * Ego dynamics
#     * Traffic violations
#     * Expert imitation
#     * Planning & navigation
#     * Scenario performance
# 2. Histograms - Histograms over metric statistics for more a granular peek inside each metric focusing on:
#     * Metric statistics (e.g. min, max, p90)
# 3. Scenarios - Low-level scenario visualizations:
#     * Time-series progression of a specific metric across a scenario
#     * Top-down visualization of the scenario across time for comparing predicted vs. expert trajectories
#
# In addition, there is a main configuration tab for selecting different simulation files for comparing planners/experiments.
#
# <br />
#
# **NOTE**: nuBoard is under heavy developement, overall functionality and aesthetics do not represent the final product!

# %% [markdown]
# ## Prepare the nuBoard config

# %%
# Location of path with all nuBoard configs
CONFIG_PATH = '../nuplan/planning/script/config/nuboard'
CONFIG_NAME = 'default_nuboard'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    'scenario_builder=nuplan_mini',  # set the database (same as simulation) used to fetch data for visualization
    f'simulation_path={[simple_simulation_folder, ml_planner_simulation_folder]}',  # nuboard file path(s), if left empty the user can open the file inside nuBoard
])
# Out:
# /home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'default_nuboard': Defaults list is missing `_self_`. See https://hydra.cc/docs/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Launch nuBoard (open in new tab - recommended)

# %%
from nuplan.planning.script.run_nuboard import main as main_nuboard

# Run nuBoard
main_nuboard(cfg)
# Out:
# INFO:bokeh.server.server:Starting Bokeh server version 2.4.3 (running on Tornado 6.5.2)
# WARNING:bokeh.server.util:Host wildcard '*' will allow connections originating from multiple (or possibly all) hostnames or IPs. Use non-wildcard values to restrict access explicitly
# INFO:bokeh.server.tornado:User authentication hooks NOT provided (default user enabled)
# 2025-11-19 00:43:04,147 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2025-11-19 00:43:04,147 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2025-11-19 00:43:04,169 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2025-11-19 00:43:04,169 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2025-11-19 00:43:04,173 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/nuboard/nuboard.py:84}  Opening Bokeh application on http://localhost:5006/
# 2025-11-19 00:43:04,173 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/nuboard/nuboard.py:84}  Opening Bokeh application on http://localhost:5006/
# 2025-11-19 00:43:04,173 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/nuboard/nuboard.py:85}  Async rendering is set to: True
# 2025-11-19 00:43:04,173 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/nuboard/nuboard.py:85}  Async rendering is set to: True
# 2025-11-19 21:33:20,572 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/nuboard/base/simulation_tile.py:172}  Minimum frame time=0.017 s
# 2025-11-19 21:33:20,572 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/nuboard/base/simulation_tile.py:172}  Minimum frame time=0.017 s
# 2025-11-19 21:33:20,606 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.0019 seconds.
# 2025-11-19 21:33:20,606 INFO {/home/gcjms/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.0019 seconds.
# INFO:tornado.access:200 GET / (::1) 828.83ms
# INFO:tornado.access:304 GET /resource/spectre.min.css (::1) 9.23ms
# INFO:tornado.access:304 GET /resource/css/scenario.css (::1) 5.63ms
# INFO:tornado.access:304 GET /resource/spectre-icons.min.css (::1) 8.76ms
# INFO:tornado.access:304 GET /resource/style.css (::1) 11.95ms
# INFO:tornado.access:304 GET /resource/spectre-exp.min.css (::1) 12.18ms
# INFO:tornado.access:304 GET /resource/css/overview.css (::1) 8.04ms
# INFO:tornado.access:304 GET /resource/css/cloud.css (::1) 9.59ms
# INFO:tornado.access:304 GET /resource/css/histogram.css (::1) 10.02ms
# INFO:tornado.access:304 GET /resource/scripts/utils.js (::1) 10.85ms
# INFO:tornado.access:304 GET /resource/motional_logo.png (::1) 2.37ms
# INFO:tornado.access:101 GET /ws (::1) 4.99ms
# INFO:bokeh.server.views.ws:WebSocket connection opened
# INFO:bokeh.server.views.ws:ServerConnection created
# 2025-11-19 21:33:20,821 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  200 GET / (::1) 828.83ms
# 2025-11-19 21:33:20,821 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  200 GET / (::1) 828.83ms
# 2025-11-19 21:33:20,853 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/spectre.min.css (::1) 9.23ms
# 2025-11-19 21:33:20,853 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/spectre.min.css (::1) 9.23ms
# 2025-11-19 21:33:20,864 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/css/scenario.css (::1) 5.63ms
# 2025-11-19 21:33:20,864 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/css/scenario.css (::1) 5.63ms
# 2025-11-19 21:33:20,868 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/spectre-icons.min.css (::1) 8.76ms
# 2025-11-19 21:33:20,868 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/spectre-icons.min.css (::1) 8.76ms
# 2025-11-19 21:33:20,872 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/style.css (::1) 11.95ms
# 2025-11-19 21:33:20,872 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/style.css (::1) 11.95ms
# 2025-11-19 21:33:20,877 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/spectre-exp.min.css (::1) 12.18ms
# 2025-11-19 21:33:20,877 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/spectre-exp.min.css (::1) 12.18ms
# 2025-11-19 21:33:20,887 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/css/overview.css (::1) 8.04ms
# 2025-11-19 21:33:20,887 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/css/overview.css (::1) 8.04ms
# 2025-11-19 21:33:20,890 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/css/cloud.css (::1) 9.59ms
# 2025-11-19 21:33:20,890 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/css/cloud.css (::1) 9.59ms
# 2025-11-19 21:33:20,892 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/css/histogram.css (::1) 10.02ms
# 2025-11-19 21:33:20,892 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/css/histogram.css (::1) 10.02ms
# 2025-11-19 21:33:20,894 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/scripts/utils.js (::1) 10.85ms
# 2025-11-19 21:33:20,894 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/scripts/utils.js (::1) 10.85ms
# 2025-11-19 21:33:20,898 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/motional_logo.png (::1) 2.37ms
# 2025-11-19 21:33:20,898 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  304 GET /resource/motional_logo.png (::1) 2.37ms
# 2025-11-19 21:33:20,994 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  101 GET /ws (::1) 4.99ms
# 2025-11-19 21:33:20,994 INFO {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  101 GET /ws (::1) 4.99ms
# WARNING:tornado.access:404 GET /favicon.ico (::1) 3.32ms
# 2025-11-19 21:33:21,173 WARNING {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  404 GET /favicon.ico (::1) 3.32ms
# 2025-11-19 21:33:21,173 WARNING {/home/gcjms/miniconda3/envs/nuplan/lib/python3.9/site-packages/tornado/web.py:2407}  404 GET /favicon.ico (::1) 3.32ms

# %% [markdown]
# ## Launch nuBoard (embedded within the notebook - alternative)

# %%
from bokeh.io import show, output_notebook
from nuplan.planning.script.run_nuboard import initialize_nuboard

# Make sure that the notebook working directory is "/notebooks" and that Jupyter was launched at the root of the repo
cfg.resource_prefix = '/notebooks/nuplan/planning/metrics/board/'  # pass CSS resources to the notebook

# Run the nuBoard
output_notebook()
nuboard = initialize_nuboard(cfg)
show(nuboard.main_page)

# %% [markdown]
# ## Launch nuBoard (command line - alternative)

# %% [markdown]
# nuBoard can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_nuboard.py
# ```
#
# Simulation files (.nuboard) can be selected under the configuration tab.
